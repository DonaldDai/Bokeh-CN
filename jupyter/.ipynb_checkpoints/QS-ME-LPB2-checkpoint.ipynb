# %%
import numpy as np
from bokeh.plotting import *
from bokeh.models import ColumnDataSource

# output to static HTML file
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="646c6215-7e8e-425d-9205-0d74ebe1e284">Loading BokehJS ...</span>
#     </div>

# %%
# prepare some date
N = 300
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)

# NEW: create a column data source for the plots to share
source = ColumnDataSource(data=dict(x=x, y0=y0, y1=y1))

TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

# create a new plot and add a renderer
left = figure(tools=TOOLS, width=350, height=350, title=None)
left.circle('x', 'y0', source=source)

# create another new plot and add a renderer
right = figure(tools=TOOLS, width=350, height=350, title=None)
right.circle('x', 'y1', source=source)

# put the subplots in a gridplot
p = gridplot([[left, right]])

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d02e7aac-b5a6-4a94-a3d1-1e9f7a949ad4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d02e7aac-b5a6-4a94-a3d1-1e9f7a949ad4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd02e7aac-b5a6-4a94-a3d1-1e9f7a949ad4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"02f6abe4-9178-42ce-bf44-43ad5dc33b57":{"roots":{"references":[{"attributes":{},"id":"bcfbb67b-11da-477b-9276-5b99d9912b39","type":"ToolEvents"},{"attributes":{"children":[{"id":"33459336-354e-45aa-b148-6c5fab68e4cf","type":"ToolbarBox"},{"id":"4d65b012-cdd1-4050-adec-b8ff61c1a383","type":"Column"}]},"id":"83ccc517-efde-43d3-8d54-4620d5f8fa07","type":"Column"},{"attributes":{"formatter":{"id":"26fa1998-764e-40d8-8bb2-df60fb4437ca","type":"BasicTickFormatter"},"plot":{"id":"057c316a-d235-4667-8bce-86a67f1079f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"6eb10f54-8546-405c-95fe-fb3afafca5cf","type":"BasicTicker"}},"id":"df8eeb4a-bc1c-457e-97c3-a1eb05ff3c32","type":"LinearAxis"},{"attributes":{"callback":null},"id":"f4daca07-f4dd-4734-bc05-b9d8ed1f8403","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"61f227d2-3ce3-45d5-a3ed-98bfb06096cb","type":"PolyAnnotation"},"plot":{"id":"057c316a-d235-4667-8bce-86a67f1079f8","subtype":"Figure","type":"Plot"}},"id":"7a733769-10dd-41f0-9b5e-f71daf72db94","type":"LassoSelectTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y0"}},"id":"7d0b8093-2517-4448-9193-4fa3ba4cf51b","type":"Circle"},{"attributes":{"plot":null,"text":null},"id":"3e49d9d2-999f-4012-9840-70598d83eb74","type":"Title"},{"attributes":{"plot":{"id":"2a7a26c2-0973-4c10-8f35-55ecabc029c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"b94f38f5-4025-4eb6-a925-565c2f7b4bbb","type":"BasicTicker"}},"id":"fadbfdbb-311e-4655-aef4-ad87f6a14a28","type":"Grid"},{"attributes":{"plot":{"id":"057c316a-d235-4667-8bce-86a67f1079f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"6eb10f54-8546-405c-95fe-fb3afafca5cf","type":"BasicTicker"}},"id":"d028edaf-6ba8-4c7a-bb26-ae4562cf44e0","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"00beb56b-e34c-4ce8-8e56-7456665f0a9f","type":"PanTool"},{"id":"561de7d0-8d88-4c15-b884-e581362b3a77","type":"WheelZoomTool"},{"id":"87083335-823d-4a7e-a8db-3c54eb542bc5","type":"BoxZoomTool"},{"id":"80277eaf-1142-45bf-b025-623ebf2a5ad0","type":"ResetTool"},{"id":"73bff295-bc82-4fae-8f3d-20735f60fb06","type":"SaveTool"},{"id":"bd40444a-2a42-4c71-b066-f9d6fd5fd70b","type":"BoxSelectTool"},{"id":"f1c94ad2-39f5-43eb-a6c8-c1a652bbd9f7","type":"LassoSelectTool"}]},"id":"eca94471-2021-418a-b2fd-6bdd1a466309","type":"Toolbar"},{"attributes":{"data_source":{"id":"75f7d231-121a-47b6-947c-14a641fb1768","type":"ColumnDataSource"},"glyph":{"id":"7d0b8093-2517-4448-9193-4fa3ba4cf51b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"634b2bd9-53b5-4fe4-bc05-c6ffc4b37799","type":"Circle"},"selection_glyph":null},"id":"bc18c65a-dacb-4188-9a3d-6a57ed95c6aa","type":"GlyphRenderer"},{"attributes":{},"id":"6eb10f54-8546-405c-95fe-fb3afafca5cf","type":"BasicTicker"},{"attributes":{},"id":"5dec26b0-ecb4-40e6-a488-ce31443f9469","type":"BasicTicker"},{"attributes":{"plot":{"id":"057c316a-d235-4667-8bce-86a67f1079f8","subtype":"Figure","type":"Plot"}},"id":"ccfc4005-34d5-4ed5-95ad-2297f7271e27","type":"PanTool"},{"attributes":{"plot":{"id":"2a7a26c2-0973-4c10-8f35-55ecabc029c9","subtype":"Figure","type":"Plot"}},"id":"561de7d0-8d88-4c15-b884-e581362b3a77","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"057c316a-d235-4667-8bce-86a67f1079f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"5dec26b0-ecb4-40e6-a488-ce31443f9469","type":"BasicTicker"}},"id":"557cfec2-71fc-4e22-a132-142bbbe20827","type":"Grid"},{"attributes":{"plot":null,"text":null},"id":"84c4cada-5899-4025-8250-5833c717d18c","type":"Title"},{"attributes":{"children":[{"id":"3d829158-b777-4848-8eb7-1c48285eee22","type":"Row"}]},"id":"4d65b012-cdd1-4050-adec-b8ff61c1a383","type":"Column"},{"attributes":{"below":[{"id":"15a6673f-e54b-4591-8950-3b7b01c3f532","type":"LinearAxis"}],"left":[{"id":"9fc03870-3cdc-4c0d-9643-40983fec0789","type":"LinearAxis"}],"plot_he ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>
